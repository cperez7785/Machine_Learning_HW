# %% [markdown]
# # Ensemble Learning
#
# ## Initial Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# ## Read the CSV and Perform Basic Data Cleaning

# %%
# Load the data
file_path = Path('Resources/LoanStats_2019Q1.csv')
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
df['home_ownership'].value_counts()
# Out:
# MORTGAGE    36219
# RENT        24613
# OWN          7346
# ANY           639
# Name: home_ownership, dtype: int64

# %%
# Create our features
X = df.drop(columns=['loan_status'])

# Create our target
y = df["loan_status"]

# %%
X_exp = pd.get_dummies(X, columns=['home_ownership',
                                   'verification_status',
                                   'issue_d',
                                   'pymnt_plan',
                                   'application_type',
                                   'initial_list_status',
                                   'next_pymnt_d',
                                   'hardship_flag',
                                   'debt_settlement_flag'])

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
X_exp
# Out:
#        loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0        10500.0    0.1719       375.35     66000.0  27.24          0.0
# 1        25000.0    0.2000       929.09    105000.0  20.23          0.0
# 2        20000.0    0.2000       529.88     56000.0  24.26          0.0
# 3        10000.0    0.1640       353.55     92000.0  31.44          0.0
# 4        22000.0    0.1474       520.39     52000.0  18.76          0.0
# ...          ...       ...          ...         ...    ...          ...
# 68812    10000.0    0.1502       346.76     26000.0   9.60          0.0
# 68813    12000.0    0.2727       368.37     63000.0  29.07          0.0
# 68814     5000.0    0.1992       185.62     52000.0  14.86          0.0
# 68815    40000.0    0.0646      1225.24    520000.0   9.96          0.0
# 68816    16000.0    0.1131       350.36     72000.0   7.02          2.0
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  total_acc  out_prncp  \
# 0                 0.0       8.0      0.0     1609.0       14.0   10204.87
# 1                 0.0      17.0      1.0    18368.0       34.0   24293.13
# 2                 0.0       8.0      0.0    13247.0       21.0   19636.79
# 3                 1.0      10.0      1.0    17996.0       23.0    9719.34
# 4                 1.0      14.0      0.0     9091.0       28.0   21614.73
# ...               ...       ...      ...        ...        ...        ...
# 68812             0.0       9.0      0.0     2684.0       20.0    9326.86
# 68813             0.0       8.0      0.0    13314.0       26.0   11706.42
# 68814             0.0       5.0      1.0     3715.0       14.0    4666.78
# 68815             1.0      21.0      0.0    59529.0       57.0   36953.94
# 68816             0.0      12.0      1.0    11882.0       39.0   15395.66
#
#        out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0
# 1                                1                           0
# 2                                1                           0
# 3                                1                           0
# 4                                1                           0
# ...                            ...                         ...
# 68812                            1                           0
# 68813                            1                           0
# 68814                            1                           0
# 68815                            1                           0
# 68816                            1                           0
#
#        initial_list_status_f  initial_list_status_w  next_pymnt_d_Apr-2019  \
# 0                          0                      1                      0
# 1                          0                      1                      0
# 2                          0                      1                      0
# 3                          0                      1                      0
# 4                          0                      1                      0
# ...                      ...                    ...                    ...
# 68812                      0                      1                      0
# 68813                      0                      1                      0
# 68814                      0                      1                      0
# 68815                      1                      0                      0
# 68816                      0                      1                      0
#
#        next_pymnt_d_May-2019  hardship_flag_N  debt_settlement_flag_N
# 0                          1                1                       1
# 1                          1                1                       1
# 2                          1                1                       1
# 3                          1                1                       1
# 4                          1                1                       1
# ...                      ...              ...                     ...
# 68812                      1                1                       1
# 68813                      1                1                       1
# 68814                      1                1                       1
# 68815                      1                1                       1
# 68816                      1                1                       1
#
# [68817 rows x 95 columns]

# %%
X_exp.describe
# Out:
# <bound method NDFrame.describe of        loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0        10500.0    0.1719       375.35     66000.0  27.24          0.0
# 1        25000.0    0.2000       929.09    105000.0  20.23          0.0
# 2        20000.0    0.2000       529.88     56000.0  24.26          0.0
# 3        10000.0    0.1640       353.55     92000.0  31.44          0.0
# 4        22000.0    0.1474       520.39     52000.0  18.76          0.0
# ...          ...       ...          ...         ...    ...          ...
# 68812    10000.0    0.1502       346.76     26000.0   9.60          0.0
# 68813    12000.0    0.2727       368.37     63000.0  29.07          0.0
# 68814     5000.0    0.1992       185.62     52000.0  14.86          0.0
# 68815    40000.0    0.0646      1225.24    520000.0   9.96          0.0
# 68816    16000.0    0.1131       350.36     72000.0   7.02          2.0
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  total_acc  out_prncp  \
# 0                 0.0       8.0      0.0     1609.0       14.0   10204.87
# 1                 0.0      17.0      1.0    18368.0       34.0   24293.13
# 2                 0.0       8.0      0.0    13247.0       21.0   19636.79
# 3                 1.0      10.0      1.0    17996.0       23.0    9719.34
# 4                 1.0      14.0      0.0     9091.0       28.0   21614.73
# ...               ...       ...      ...        ...        ...        ...
# 68812             0.0       9.0      0.0     2684.0       20.0    9326.86
# 68813             0.0       8.0      0.0    13314.0       26.0   11706.42
# 68814             0.0       5.0      1.0     3715.0       14.0    4666.78
# 68815             1.0      21.0      0.0    59529.0       57.0   36953.94
# 68816             0.0      12.0      1.0    11882.0       39.0   15395.66
#
#        out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0           10204.87       355.29           355.29           295.13
# 1           24293.13       873.53           873.53           706.87
# 2           19636.79       485.44           485.44           363.21
# 3            9719.34       335.33           335.33           280.66
# 4           21614.73       484.36           484.36           385.27
# ...              ...          ...              ...              ...
# 68812        9326.86      1019.42          1019.42           673.14
# 68813       11706.42      1086.93          1086.93           293.58
# 68814        4666.78       571.33           571.33           333.22
# 68815       36953.94      3661.36          3661.36          3046.06
# 68816       15395.66      1041.03          1041.03           604.34
#
#        total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0              60.16                 0.0         0.0                      0.0
# 1             166.66                 0.0         0.0                      0.0
# 2             122.23                 0.0         0.0                      0.0
# 3              54.67                 0.0         0.0                      0.0
# 4              99.09                 0.0         0.0                      0.0
# ...              ...                 ...         ...                      ...
# 68812         346.28                 0.0         0.0                      0.0
# 68813         793.35                 0.0         0.0                      0.0
# 68814         238.11                 0.0         0.0                      0.0
0
#
#        total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0                38199.0          2000.0                     61987.0
# 1                60641.0         41200.0                     49197.0
# 2                45684.0          7500.0                     43144.0
# 3                68784.0         19700.0                     76506.0
# 4                25919.0         27600.0                     20000.0
# ...                  ...             ...                         ...
# 68812             6798.0         11300.0                      5425.0
# 68813            60350.0         13500.0                     62939.0
# 68814            18611.0          3600.0                     18492.0
# 68815            95958.0        100800.0                     78634.0
# 68816            74835.0         23000.0                     63090.0
#
#        home_ownership_ANY  home_ownership_MORTGAGE  home_ownership_OWN  \
# 0                       0                        0                   0
# 1                       0                        1                   0
# 2                       0                        1                   0
# 3                       0                        0                   0
# 4                       0                        1                   0
# ...                   ...                      ...                 ...
# 68812                   0                        0                   0
# 68813                   0                        0                   0
# 68814                   0                        1                   0
# 68815                   0                        1                   0
# 68816                   0                        1                   0
#
#        home_ownership_RENT  verification_status_Not Verified  \
# 0                        1                                 0
# 1                        0                                 0
# 2                        0                                 0
# 3                        1                                 0
# 4                        0                                 1
# ...                    ...                               ...
# 68812                    1                                 0
# 68813                    1                                 1
# 68814                    0                                 0
# 68815                    0                                 0
# 68816                    0                                 0
#
#        verification_status_Source Verified  verification_status_Verified  \
# 0                                        1                             0
# 1                                        0                             1
# 2                                        0                             1
# 3                                        0                             1
# 4                                        0                             0
# ...                                    ...                           ...
# 68812                                    1                             0
# 68813                                    0                             0
# 68814                                    1                             0
# 68815                                    0                             1
# 68816                                    0                             1
#
#        issue_d_Feb-2019  issue_d_Jan-2019  issue_d_Mar-2019  pymnt_plan_n  \
# 0                     0                 0                 1             1
# 1                     0                 0                 1             1
# 2                     0                 0                 1             1
# 3                     0                 0                 1             1
# 4                     0                 0                 1             1
# ...                 ...               ...               ...           ...
# 68812                 0                 1                 0             1
# 68813                 0                 1                 0             1
# 68814                 0                 1                 0             1
# 68815                 0                 1                 0             1
# 68816                 0                 1                 0             1
#
#        application_type_Individual  application_type_Joint App  \
# 0                                1                           0
# 1                                1                           0
# 2                                1                           0
# 3                                1                           0
# 4                                1                           0
# ...                            ...                         ...
# 68812                            1                           0
# 68813                            1                           0
# 68814                            1                           0
# 68815                            1                           0
# 68816                            1                           0
#
#        initial_list_status_f  initial_list_status_w  next_pymnt_d_Apr-2019  \
# 0                          0                      1                      0
# 1                          0                      1                      0
# 2                          0                      1                      0
# 3                          0                      1                      0
# 4                          0                      1                      0
# ...                      ...                    ...                    ...
# 68812                      0                      1                      0
# 68813                      0                      1                      0
# 68814                      0                      1                      0
# 68815                      1                      0                      0
# 68816                      0                      1                      0
#
#        next_pymnt_d_May-2019  hardship_flag_N  debt_settlement_flag_N
# 0                          1                1                       1
# 1                          1                1                       1
# 2                          1                1                       1
# 3                          1                1                       1
# 4                          1                1                       1
# ...                      ...              ...                     ...
# 68812                      1                1                       1
# 68813                      1                1                       1
# 68814                      1                1                       1
# 68815                      1                1                       1
# 68816                      1                1                       1
#
# [68817 rows x 95 columns]>

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
# Split the X and y into X_train, X_test, y_train, y_test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_exp, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
X_train.shape
# Out:
# (51612, 95)

# %% [markdown]
# ## Data Pre-Processing
#
# Scale the training and testing data using the `StandardScaler` from `sklearn`. Remember that when scaling the data, you only scale the features data (`X_train` and `X_testing`).

# %%
# Create the StandardScaler instance
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
# When fitting scaling functions, only train on the training dataset
X_scaler = scaler.fit(X_train)
X_scaler
# Out:
# StandardScaler()

# %%
# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled.shape
# Out:
# (51612, 95)

# %% [markdown]
# ## Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Display the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier only, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.ensemble import EasyEnsembleClassifier
from imblearn.metrics import classification_report_imbalanced

# %%
# Resample the training data with the BalancedRandomForestClassifier
brf = BalancedRandomForestClassifier(n_estimators=100, random_state=1)

brf.fit(X_train, y_train)
# Out:
# BalancedRandomForestClassifier(random_state=1)

# %%
# Calculated the balanced accuracy score
y_prediction = brf.predict(X_test)
balanced_accuracy_score(y_test, y_prediction)
# Out:
# 0.8277272159573911

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_prediction)
# Out:
# array([[   66,    21],
#        [ 1766, 15352]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_prediction))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.04      0.76      0.90      0.07      0.82      0.67        87
#    low_risk       1.00      0.90      0.76      0.95      0.82      0.69     17118
#
# avg / total       0.99      0.90      0.76      0.94      0.82      0.69     17205

# %%
# List the features sorted in descending order by feature importance
importances = brf.feature_importances_

sorted(zip(brf.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.08384161748307747, 'initial_list_status'),
#  (0.06760078394762778, 'revol_bal'),
#  (0.05861706782132518, 'total_acc'),
#  (0.05638305506152568, 'out_prncp'),
#  (0.04653402246578966, 'total_rec_prncp'),
#  (0.0262179410121114, 'int_rate'),
#  (0.01937671064024165, 'debt_settlement_flag'),
#  (0.01905860446904421, 'open_il_12m'),
#  (0.018082290401498988, 'total_rev_hi_lim'),
#  (0.016857654261507565, 'delinq_2yrs'),
#  (0.016469126811688686, 'annual_inc'),
#  (0.01624711952098658, 'max_bal_bc'),
#  (0.015680935310031778, 'installment'),
#  (0.015371360400431858, 'home_ownership'),
#  (0.014972096050258442, 'last_pymnt_amnt'),
#  (0.014879146354605516, 'delinq_amnt'),
#  (0.014842420215093861, 'num_tl_op_past_12m'),
#  (0.014797675676263364, 'num_tl_30dpd'),
#  (0.014594686799565111, 'pub_rec'),
#  (0.013924182636262335, 'open_il_24m'),
#  (0.013893164095629839, 'open_acc'),
#  (0.013485731839459579, 'loan_amnt'),
#  (0.012723184086139788, 'acc_open_past_24mths'),
#  (0.012584210013563605, 'all_util'),
#  (0.012571243320210807, 'tot_cur_bal'),
#  (0.012534921722898135, 'num_tl_90g_dpd_24m'),
#  (0.012082910102813742, 'inq_last_12m'),
#  (0.011851451782033978, 'tot_coll_amt'),
#  (0.011510511326905806, 'mths_since_rcnt_il'),
#  (0.011339159047430868, 'pct_tl_nvr_dlq'),
#  (0.011220577951750972, 'num_accts_ever_120_pd'),
#  (0.011033130530352193, 'inq_last_6mths'),
#  (0.010787630290720352, 'chargeoff_within_12_mths'),
#  (0.010431855583898293, 'mo_sin_rcnt_rev_tl_op'),
#  (0.01040685209510576, 'acc_now_delinq'),
#  (0.010130425752870794, 'pymnt_plan'),
#  (0.009589374327630771, 'mths_since_recent_bc'),
#  (0.009270028538618132, 'il_util'),
#  (0.009255460955456285, 'bc_open_to_buy'),
#  (0.00914389855308212, 'mths_since_recent_inq'),
#  (0.009003313828620392, 'open_rv_12m'),
#  (0.008913713137180864, 'mort_acc'),
#  (0.00880681317893733, 'num_actv_bc_tl'),
#  (0.008629500953341604, 'open_rv_24m'),
#  (0.008533862421552935, 'mo_sin_old_rev_tl_op'),
#  (0.008276713831954673, 'num_rev_accts'),
#  (0.007604707318026315, 'num_actv_rev_tl'),
#  (0.0074780815542790525, 'next_pymnt_d'),
#  (0.00744616915614222, 'avg_cur_bal'),
#  (0.00738439806194435, 'bc_util'),
#  (0.007380135666031215, 'collections_12_mths_ex_med'),
#  (0.007349633681252658, 'num_op_rev_tl'),
#  (0.007188215963991252, 'mo_sin_rcnt_tl'),
#  (0.006818261915486416, 'open_act_il'),
#  (0.006727102007803252, 'num_rev_tl_bal_gt_0'),
#  (0.006633260265110945, 'application_type'),
#  (0.005892648432475059, 'total_bal_il'),
#  (0.005633099247094625, 'out_prncp_inv'),
#  (0.005441017649608711, 'issue_d'),
#  (0.0050930213345886195, 'open_acc_6m'),
#  (0.005092848179837313, 'verification_status'),
#  (0.005056503722607311, 'policy_code'),
#  (0.0034055074282567936, 'hardship_flag'),
#  (0.0033505559064781806, 'mo_sin_old_il_acct'),
#  (0.0029096531260145333, 'collection_recovery_fee'),
#  (0.0028757899134867495, 'tot_hi_cred_lim'),
#  (0.0021757225163146756, 'total_bal_ex_mort'),
#  (0.0021220569613964427, 'total_bc_limit'),
#  (0.0020045786324625003, 'dti'),
#  (0.0017325475096051912, 'total_il_high_credit_limit'),
#  (0.0015179593096446516, 'num_il_tl'),
#  (0.0014647133926215961, 'tax_liens'),
#  (0.0013777123661757689, 'pub_rec_bankruptcies'),
#  (0.0009817855638313336, 'num_sats'),
#  (0.00030669490553197616, 'total_rec_int'),
#  (0.0001244559992093813, 'percent_bc_gt_75'),
#  (5.711040193798812e-05, 'inq_fi'),
#  (0.0, 'total_rec_late_fee'),
#  (0.0, 'total_pymnt_inv'),
#  (0.0, 'total_pymnt'),
#  (0.0, 'total_cu_tl'),
#  (0.0, 'recoveries'),
#  (0.0, 'num_tl_120dpd_2m'),
#  (0.0, 'num_bc_tl'),
#  (0.0, 'num_bc_sats')]

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
# Train the Classifier
eec = EasyEnsembleClassifier(n_estimators=100, random_state=1)
eec.fit(X_train, y_train)
# Out:
# EasyEnsembleClassifier(n_estimators=100, random_state=1)

# %%
# Calculated the balanced accuracy score
y_prd = eec.predict(X_test)
balanced_accuracy_score(y_test, y_prd)
# Out:
# 0.925427358175101

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_prd);

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_prd))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.07      0.91      0.94      0.14      0.93      0.85        87
#    low_risk       1.00      0.94      0.91      0.97      0.93      0.86     17118
#
# avg / total       0.99      0.94      0.91      0.97      0.93      0.86     17205

# %% [markdown]
# ### Final Questions
#
# 1. Which model had the best balanced accuracy score?
#
#     bOTH SCORE THE SAME AVG.
#
# 2. Which model had the best recall score?
#
#     SECOND CHOICE HAS THE BTTER SCORE
#
# 3. Which model had the best geometric mean score?
#
#     SECOND ONE
#
# 4. What are the top three features?
#
#     THE PRE, F1, AND REC
